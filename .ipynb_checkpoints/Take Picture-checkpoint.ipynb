# %%
from pathlib import Path
from skimage.io import imread
from skimage.transform import resize
from sklearn.utils import Bunch

import matplotlib.pyplot as plt

from sklearn import datasets
import cv2

import pandas as pd
import numpy as np

# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler


import os
from PIL import Image
import sys


from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics

# %% [markdown]
# # Take Input

# %%
Folder_name=input('Name:')
Folder_id=input('ID:')
# Out:
# Name:Gulam Kibria Chowdhury
# ID:170103020033

# %% [markdown]
# # Create Folder

# %%
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)
        

createFolder('C:\\Users\\G.K\\Face Recognition Attendance System\\traning_image\\'+str(Folder_name)+'_'+str(Folder_id))

# %% [markdown]
# # Take Traning Image

# %%
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')#xml file for face detection
video_capture = cv2.VideoCapture(0)#open a vedi
img_counter = 1#count level 
run=0
while True:
    # Capture frame-by-frame
    ret, frame = video_capture.read()#read a image from vedio
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)#convert to gray scale
    faces = faceCascade.detectMultiScale(gray, 1.3, 5)#face size
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)#show face position in a frame
        roi_gray = gray[y:y+h, x:x+w]#gray scale crop
        roi_color = frame[y:y+h, x:x+w]#color image scale crop
    k=cv2.waitKey(200)
    cv2.imshow('FaceDetection', frame)

    if img_counter ==51: #ESC Pressed
        break
    elif k%256 == 32:
        run=1
    if(run==1):
        img_name = 'C:\\Users\\G.K\\Face Recognition Attendance System\\traning_image\\'+str(Folder_name)+'_'+str(Folder_id)+'\\'+str(Folder_name)+'.'+str(Folder_id)+'.'+'{}.jpg'.format(img_counter)
        cv2.imwrite(img_name, roi_gray)
        print("{} written!".format(img_name))
        img_counter += 1
        
# When everything is done, release the capture
video_capture.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.1.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.2.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.3.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.4.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.5.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.6.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.7.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.8.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.9.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.10.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.11.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.12.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.13.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.14.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.15.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.16.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.17.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.18.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.19.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.20.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.21.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.22.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.23.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.24.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.25.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.26.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.27.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.28.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.29.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.30.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.31.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.32.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.33.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.34.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.35.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.36.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.37.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.38.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.39.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.40.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.41.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.42.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.43.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.44.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.45.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.46.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.47.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.48.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.49.jpg written!
# C:\Users\G.K\Face Recognition Attendance System\traning_image\Gulam Kibria Chowdhury_170103020033\Gulam Kibria Chowdhury.170103020033.50.jpg written!
